# %%
import pandas as pd

# %%
df = pd.read_csv('food_coded.csv')
df
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0      2.4       2          1               430           NaN           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           NaN           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           NaN           315.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 61 columns):
# GPA                             123 non-null object
# Gender                          125 non-null int64
# breakfast                       125 non-null int64
# calories_chicken                125 non-null int64
# calories_day                    106 non-null float64
# calories_scone                  124 non-null float64
# coffee                          125 non-null int64
# comfort_food                    124 non-null object
# comfort_food_reasons            124 non-null object
# comfort_food_reasons_coded      106 non-null float64
# cook                            122 non-null float64
# comfort_food_reasons_coded.1    125 non-null int64
# cuisine                         108 non-null float64
# diet_current                    124 non-null object
# diet_current_coded              125 non-null int64
# drink                           123 non-null float64
# ...

# %%
new_df = df[["cook","eating_out","employment","ethnic_food","exercise","fruit_day","income","on_off_campus",
       "pay_meal_out","sports","veggies_day"]]

# %%
new_df
# Out:
#      cook  eating_out  employment  ethnic_food  exercise  fruit_day  income  \
# 0     2.0           3         3.0            1       1.0          5     5.0
# 1     3.0           2         2.0            4       1.0          4     4.0
# 2     1.0           2         3.0            5       2.0          5     6.0
# 3     2.0           2         3.0            5       3.0          4     6.0
# 4     1.0           2         2.0            4       1.0          4     6.0
# ..    ...         ...         ...          ...       ...        ...     ...
# 120   3.0           2         1.0            4       2.0          5     4.0
# 121   3.0           4         3.0            3       2.0          4     2.0
# 122   3.0           3         3.0            5       2.0          4     2.0
# 123   3.0           5         2.0            2       1.0          5     4.0
# 124   NaN           1         2.0            3       2.0          3     5.0
#
#      on_off_campus  pay_meal_out  sports  veggies_day
# ...

# %%
new_df.isnull().sum(axis=0)
# Out:
# cook              3
# eating_out        0
# employment        9
# ethnic_food       0
# exercise         13
# fruit_day         0
# income            1
# on_off_campus     1
# pay_meal_out      0
# sports            2
# veggies_day       0
# dtype: int64

# %%
new_df.isnull().sum().sum()
# Out:
# 29

# %%
new_df.astype(int)
# Out:
#      cook  eating_out  employment  ethnic_food  exercise  fruit_day  income  \
# 0       2           3           3            1         1          5       5
# 1       3           2           2            4         1          4       4
# 2       1           2           3            5         2          5       6
# 3       2           2           3            5         3          4       6
# 4       1           2           2            4         1          4       6
# ..    ...         ...         ...          ...       ...        ...     ...
# 120     3           2           1            4         2          5       4
# 121     3           4           3            3         2          4       2
# 122     3           3           3            5         2          4       2
# 123     3           5           2            2         1          5       4
# 124     0           1           2            3         2          3       5
#
#      on_off_campus  pay_meal_out  sports  veggies_day
# ...

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 11 columns):
# cook             122 non-null float64
# eating_out       125 non-null int64
# employment       116 non-null float64
# ethnic_food      125 non-null int64
# exercise         112 non-null float64
# fruit_day        125 non-null int64
# income           124 non-null float64
# on_off_campus    124 non-null float64
# pay_meal_out     125 non-null int64
# sports           123 non-null float64
# veggies_day      125 non-null int64
# dtypes: float64(6), int64(5)
# memory usage: 10.9 KB

# %%
new_df.fillna(0, inplace = True)
# Out:
# D:\anaconda\lib\site-packages\pandas\core\frame.py:4244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   **kwargs

# %%
new_df.isnull().sum()
# Out:
# cook             0
# eating_out       0
# employment       0
# ethnic_food      0
# exercise         0
# fruit_day        0
# income           0
# on_off_campus    0
# pay_meal_out     0
# sports           0
# veggies_day      0
# dtype: int64

# %%
new_df.to_csv('food choices.csv', index = False)

# %%
new_df1 = pd.read_csv('food choices.csv')
new_df1
# Out:
#      cook  eating_out  employment  ethnic_food  exercise  fruit_day  income  \
# 0     2.0           3         3.0            1       1.0          5     5.0
# 1     3.0           2         2.0            4       1.0          4     4.0
# 2     1.0           2         3.0            5       2.0          5     6.0
# 3     2.0           2         3.0            5       3.0          4     6.0
# 4     1.0           2         2.0            4       1.0          4     6.0
# ..    ...         ...         ...          ...       ...        ...     ...
# 120   3.0           2         1.0            4       2.0          5     4.0
# 121   3.0           4         3.0            3       2.0          4     2.0
# 122   3.0           3         3.0            5       2.0          4     2.0
# 123   3.0           5         2.0            2       1.0          5     4.0
# 124   0.0           1         2.0            3       2.0          3     5.0
#
#      on_off_campus  pay_meal_out  sports  veggies_day
# ...

# %%
new_df1.astype(int)
# Out:
#      cook  eating_out  employment  ethnic_food  exercise  fruit_day  income  \
# 0       2           3           3            1         1          5       5
# 1       3           2           2            4         1          4       4
# 2       1           2           3            5         2          5       6
# 3       2           2           3            5         3          4       6
# 4       1           2           2            4         1          4       6
# ..    ...         ...         ...          ...       ...        ...     ...
# 120     3           2           1            4         2          5       4
# 121     3           4           3            3         2          4       2
# 122     3           3           3            5         2          4       2
# 123     3           5           2            2         1          5       4
# 124     0           1           2            3         2          3       5
#
#      on_off_campus  pay_meal_out  sports  veggies_day
# ...
